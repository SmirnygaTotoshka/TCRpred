# %% [markdown]
# # Processsing antigens for MHC I. Experiment 1

# %% [markdown]
# __*A. Smirnov*__

# %% [markdown]
# Цель - Посмотреть, сколько пептидов, нарезанных по правилам из литературы, получится в сравнении с экспериментальной базой данных из статьи(https://doi.org/10.1038/s41597-020-0487-6)
