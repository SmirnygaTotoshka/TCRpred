# %%
import os
import sys
import pandas as pd
from getpass import getpass

# %%
sys.path.append('../../../data_prepare')

# %%
from IEDB import IEDB

# %%
iedb = IEDB("81.177.141.179","iedb_svc",getpass())

# %%
raw_data = iedb.acquire()
raw_data.head()
# Out:
# tcell
# c:\Users\anton\Documents\РНИМУ\TCRpred\notebooks\tests\data_prepare\../../../data_prepare\IEDB.py:86: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   for chunk in pd.read_sql(f"SELECT * FROM {name};", con = connection, chunksize = chunk_size):
# c:\Users\anton\Documents\РНИМУ\TCRpred\notebooks\tests\data_prepare\../../../data_prepare\IEDB.py:87: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   tbl = pd.concat([tbl, chunk], ignore_index = False)
# curated_epitope
# ...
