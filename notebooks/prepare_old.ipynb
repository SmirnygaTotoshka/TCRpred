# %%
import pandas as pd
import mhcgnomes

# %% [markdown]
# ## CDR3a_MHC

# %%
cdr3a_mhc = pd.read_csv("/projects/rat_gravitation/anton_disser/TCR-Pred/03_26/data/v2023/old/CDR3a_MHC.csv", sep = ";")
cdr3a_mhc.head()
# Out:
#   TCR_chain CDR3_TCR_sequence    Epitope host_species class   MHC_allele  \
# 0     alpha    AMSLYYGGSQGNLI  KIFGSLAFL        Human     I  HLA-A*02:01
# 1     alpha    AMSLYYGGSQGNLI  KIFGSLAFL        Human     I  HLA-A*02:01
# 2     alpha     AVSVEETSGSRLT  GILGFVFTL        Human     I  HLA-A*02:01
# 3     alpha    ALSEAGTGGSYIPT  GILGFVFTL        Human     I  HLA-A*02:01
# 4     alpha          AVIDYKLS  YLYDRLLRI        Human     I  HLA-A*02:01
#
#     accession database_access                               protein_name  \
# 0  AAA75493.1         GenPept                              HER2 receptor
# 1  AAA75493.1         GenPept                              HER2 receptor
# 2    P03485.1         GenPept                           Matrix protein 1
# 3    P03485.1         GenPept                           Matrix protein 1
# 4    Q14691.1         GenPept  DNA replication complex GINS protein PSF1
#
#                                       source_species Source good_mhc  \
# ...

# %%
cdr3a_mhc.query("host_species == 'Human'").to_csv("/projects/rat_gravitation/anton_disser/TCR-Pred/03_26/data/v2023/cdr3alpha_mhc_human.csv", sep =";")
cdr3a_mhc.query("host_species == 'Mouse'").to_csv("/projects/rat_gravitation/anton_disser/TCR-Pred/03_26/data/v2023/cdr3alpha_mhc_mouse.csv", sep =";")

# %% [markdown]
# ## CDR3b_MHC

# %%
cdr3b_mhc = pd.read_csv("/projects/rat_gravitation/anton_disser/TCR-Pred/03_26/data/v2023/old/CDR3b_MHC.csv", sep = ";")
cdr3b_mhc.head()
# Out:
# /scratch/ipykernel_1615770/1716130328.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   cdr3b_mhc = pd.read_csv("/projects/rat_gravitation/anton_disser/TCR-Pred/03_26/data/v2023/old/CDR3b_MHC.csv", sep = ";")
#   TCR_chain  CDR3_TCR_sequence    Epitope host_species class   MHC_allele  \
# 0      beta  ASSLEIFGGIADTDTQY  KIFGSLAFL        Human     I  HLA-A*02:01
# 1      beta  ASSLEIFGGIADTDTQY  KIFGSLAFL        Human     I  HLA-A*02:01
# 2      beta        ASSIRSSYEQY  GILGFVFTL        Human     I  HLA-A*02:01
# 3      beta        ASSFFHNNEQF  GILGFVFTL        Human     I  HLA-A*02:01
# 4      beta        ASSMFVGQPQH  GILGFVFTL        Human     I  HLA-A*02:01
#
#     accession database_access      protein_name  \
# 0  AAA75493.1         GenPept     HER2 receptor
# 1  AAA75493.1         GenPept     HER2 receptor
# 2    P03485.1         GenPept  Matrix protein 1
# 3    P03485.1         GenPept  Matrix protein 1
# ...

# %%
cdr3b_mhc.query("host_species == 'Human'").to_csv("/projects/rat_gravitation/anton_disser/TCR-Pred/03_26/data/v2023/cdr3beta_mhc_human.csv", sep =";")
cdr3b_mhc.query("host_species == 'Mouse'").to_csv("/projects/rat_gravitation/anton_disser/TCR-Pred/03_26/data/v2023/cdr3beta_mhc_mouse.csv", sep =";")

# %% [markdown]
# ## CDR3a_epitope

# %%
cdr3a_epi = pd.read_csv("/projects/rat_gravitation/anton_disser/TCR-Pred/03_26/data/v2023/old/CDR3a_epitope.csv", sep = ";")
cdr3a_epi.head()
# Out:
#   TCR_chain CDR3_TCR_sequence host_species     Epitope       accession  \
# 0     alpha    AMSLYYGGSQGNLI        Human   KIFGSLAFL      AAA75493.1
# 1     alpha    AMSLYYGGSQGNLI        Human   KIFGSLAFL      AAA75493.1
# 2     alpha     ATVLRMDSSYKLI        Human  TPRVTGGGAM  YP_002608275.1
# 3     alpha     AYRSARDSSYKLI        Human  TPRVTGGGAM  YP_002608275.1
# 4     alpha     AVSVEETSGSRLT        Human   GILGFVFTL        P03485.1
#
#   database_access           protein_name  \
# 0         GenPept          HER2 receptor
# 1         GenPept          HER2 receptor
# 2         GenPept  tegument protein pp65
# 3         GenPept  tegument protein pp65
# 4         GenPept       Matrix protein 1
#
#                                       source_species Source
# 0                               Homo sapiens (human)   IEDB
# 1                               Homo sapiens (human)   IEDB
# 2        Human herpesvirus 5 (Human cytomegalovirus)   IEDB
# ...

# %%
cdr3a_epi.query("host_species == 'Human'").to_csv("/projects/rat_gravitation/anton_disser/TCR-Pred/03_26/data/v2023/cdr3alpha_epitope_human.csv", sep =";")
cdr3a_epi.query("host_species == 'Mouse'").to_csv("/projects/rat_gravitation/anton_disser/TCR-Pred/03_26/data/v2023/cdr3alpha_epitope_mouse.csv", sep =";")

# %% [markdown]
# ## CDR3b_epitope

# %%
cdr3b_epi = pd.read_csv("/projects/rat_gravitation/anton_disser/TCR-Pred/03_26/data/v2023/old/CDR3b_epitope.csv", sep = ";")
cdr3b_epi.head()
# Out:
# /scratch/ipykernel_1615770/3922694492.py:1: DtypeWarning: Columns (9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   cdr3b_epi = pd.read_csv("/projects/rat_gravitation/anton_disser/TCR-Pred/03_26/data/v2023/old/CDR3b_epitope.csv", sep = ";")
#   TCR_chain  CDR3_TCR_sequence host_species     Epitope       accession  \
# 0      beta  ASSLEIFGGIADTDTQY        Human   KIFGSLAFL      AAA75493.1
# 1      beta  ASSLEIFGGIADTDTQY        Human   KIFGSLAFL      AAA75493.1
# 2      beta     ASSLIGVSSYNEQF        Human  TPRVTGGGAM  YP_002608275.1
# 3      beta    ASSDHSVTGISSPLH        Human  TPRVTGGGAM  YP_002608275.1
# 4      beta       ASSPGGGKETQY        Human   DEEDAIAAY      AAR31419.1
#
#   database_access           protein_name  \
# 0         GenPept          HER2 receptor
# 1         GenPept          HER2 receptor
# 2         GenPept  tegument protein pp65
# 3         GenPept  tegument protein pp65
# 4         GenPept                  UL123
#
# ...

# %%
cdr3b_epi.query("host_species == 'Human'").to_csv("/projects/rat_gravitation/anton_disser/TCR-Pred/03_26/data/v2023/cdr3beta_epitope_human.csv", sep =";")
cdr3b_epi.query("host_species == 'Mouse'").to_csv("/projects/rat_gravitation/anton_disser/TCR-Pred/03_26/data/v2023/cdr3beta_epitope_mouse.csv", sep =";")
